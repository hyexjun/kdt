# %% [markdown]
# #### 객체지향 프로그래밍 개념을 이용하여 노트북 프로그램 만들기
# - Note를 정리하는 프로그램이다
# - 사용자는 Note에 콘텐츠를 적을 수 있다
# - Note는 Notebook에 삽입된다
# - Note는 Title이 있다
# - Notebook은 Note가 삽입될 때 페이지를 생성하며, 최대 300 페이지까지 저장할 수 있다
# - 300페이지를 넘기면 Note를 더는 삽입하지 못한다

# %%
class Note:
    def __init__(self, contents):
        pass

    def write_content(self, content):
        note_title = input("노트 제목 :")
        content = input("노트 내용 :")
        print(note_title, "노트를 추가하였습니다.")

        note_page = [note_title,  # 요기 엔터치고 싶어요 content]
        self.note_list.append(note_title)

    def remove_all(self):
        write_content.clear()       # 이거 이런 식으로 되나? 일단 실험



class Notebook:

    all_Notes = {'제목1': '내용1', '제목2': '내용2'}

    def __init__(self, notes, title, page_number):
        pass

    def add_note(self, note):


    def remove_note(self, note):
        pass

    def get_number_of_pages(self):
        for i in range(len(self.customer)):
            customer_form = '{0}. [제목] {1}'.format(i+1, all_Notes.keys())


    @ staticmethod
    def printMenu():
        print("=== << 노트 관리 메뉴 >> ===")
        print("1. 노트 페이지 전체 조회")
        print("2. 노트 추가")
        print("3. 노트 삭제")
        print("9. 종료")
        print("============================")

    @ staticmethod
    def add_noteprint():
        print("================================")
        print("새로운 노트 페이지를 추가합니다.")
        print("================================")

    @ staticmethod
    def del_noteprint():
        print("================================")
        print("노트 페이지를 삭제합니다.")
        print("================================")


create_Note = Notebook()

while 1:
    create_Note.printMenu()
    Menu_input = int(input("## 메뉴 입력 :"))
    if Menu_input == 1:
        create_Note.get_number_of_pages()
    elif Menu_input == 2:
        if 노트 페이지 수가 299까지는 생성 가능
            create_Note.add_noteprint()
            create_Note.add_note()
        else:
            print("더 이상 노트를 추가할 수 없습니다. 추가를 원할 경우 기존 노트를 삭제하세요.")
    elif Menu_input == 3:
        create_Note.del_noteprint()
        create_Note.delete()
    elif Menu_input == 9:
        print("프로그램을 종료합니다.")
        break
