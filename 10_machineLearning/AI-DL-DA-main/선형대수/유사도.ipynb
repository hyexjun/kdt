# %%
'''
유사도를 알아보는 4가지 방법

1)유클리드 거리
2)맨하탄 거리
3)민코프스키 거리
4) 코사인 유사도

'''

# %%
from sklearn.datasets import load_digits  #손글씨데이터 호출
import matplotlib.gridspec as gridspec  #그려보고
import numpy as np   #벡터의 놈 계산
'''
벡터의 놈은 여러 종류가 있는데,
여기서는 llxll 놈.
이 놈은  
벡터 x의 성분의 절대값을 모두 더한 것

'''
import matplotlib.pylab as plt
plt.figure(figsize=(9,9))

# %%
digits=load_digits()
digits
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
d1= digits.images[0]
d2= digits.images[10]
d3= digits.images[1]
d4= digits.images[11]   #행렬임

# %%
v1= d1.reshape(64,1)  #유사도를 알아보기 위해 벡터로 바꿀 거임.  
v2= d2.reshape(64,1) 
v3= d3.reshape(64,1) 
v4= d4.reshape(64,1)
