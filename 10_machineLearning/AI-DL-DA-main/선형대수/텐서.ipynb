# %%
import numpy as np

# %%
#수학이 바라보는 tensor, 물리가 바라보는 tensor, 데이터사이언스에서 보는 tensor 약간 상이하다. 

from scipy import misc #이미지 가져오고
import matplotlib.pyplot as plt  #이미지 그리려고

# %%
face= misc.face()

# %%
face
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
face.shape  #넘파이 변수
# Out:
# (768, 1024, 3)

# %%
# 차원이 3개네.
# 행렬이 3개가 쌓여있다는 거.

face[:, :, 0]   
#이거는 첫번째 행렬을 가져온 것.
# Out:
# array([[121, 138, 153, ..., 119, 131, 139],
#        [ 89, 110, 130, ..., 118, 134, 146],
#        [ 73,  94, 115, ..., 117, 133, 144],
#        ...,
#        [ 87,  94, 107, ..., 120, 119, 119],
#        [ 85,  95, 112, ..., 121, 120, 120],
#        [ 85,  97, 111, ..., 120, 119, 118]], dtype=uint8)

# %%
face[:, :, 0].shape
# Out:
# (768, 1024)

# %%
#768행, 1024열로 이루어진 (첫번째) 행렬.

# %%
face[:, :, 1]
# Out:
# array([[112, 129, 144, ..., 126, 136, 144],
#        [ 82, 103, 122, ..., 125, 141, 153],
#        [ 66,  87, 108, ..., 126, 142, 153],
#        ...,
#        [106, 110, 124, ..., 158, 157, 158],
#        [101, 111, 127, ..., 157, 156, 156],
#        [101, 113, 126, ..., 156, 155, 154]], dtype=uint8)

# %%
face[:, :, 1].shape
# Out:
# (768, 1024)

# %%
#두번째 행렬도 행렬 사이즈 같음.
#face는 텐서.

# %%
plt.imshow(face)

# %%
#첫번쨰 행렬이 red, 두번째가 green, 세번쨰가 blue 픽셀 값을 가지는 행렬. 이 세가지가 겹쳐진 텐서가 이미지인 거고.

# %%
plt.imshow(face[:, :, 0])

# %%
plt.imshow(face[:, :, 1])   #행렬을 각각 가져옴

# %%
plt.imshow(face[:, :, :])   # 모든 행렬을 가져오면 이렇게 완성

# %%
face[:, :, 0]
# Out:
# array([[121, 138, 153, ..., 119, 131, 139],
#        [ 89, 110, 130, ..., 118, 134, 146],
#        [ 73,  94, 115, ..., 117, 133, 144],
#        ...,
#        [ 87,  94, 107, ..., 120, 119, 119],
#        [ 85,  95, 112, ..., 121, 120, 120],
#        [ 85,  97, 111, ..., 120, 119, 118]], dtype=uint8)

# %%
face[:, :, 0].shape    #768행 x 1024열
# Out:
# (768, 1024)

# %%
face   #이거 구조는 왜 이렇게 되는 걸까?
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
'''
각 행렬의 1행1열에 해당되는 게 [] 안에 들어가고,
그다음은 각 행렬의 1행2열에 들어가는 게 []안에 묶여있고..
'''
face.shape
# Out:
# (768, 1024, 3)
